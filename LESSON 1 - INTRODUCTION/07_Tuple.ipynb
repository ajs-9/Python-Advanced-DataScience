# %% [markdown]
# #### Tuples

# %% [markdown]
# A tuple is an immutable data type written within round brackets in python.

# %%
x = (3, 4, 6)
print(type(x))
# Out:
# <class 'tuple'>

# %%
print(x[1]) #same as list - indexing
# Out:
# 4
