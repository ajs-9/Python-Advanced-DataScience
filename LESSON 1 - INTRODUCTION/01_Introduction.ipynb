# %% [markdown]
# #### What is python

# %% [markdown]
# It is a object oriented programming language developed by Guido von Rossum in 1989 and released in 1991.

# %% [markdown]
# #### Features

# %% [markdown]
# Easy to use, cross platform, free and open source, object-oriented langugae, Large Standard library, Memory Management

# %%
print("Hello World") # easy to use...
# Out:
# Hello World
