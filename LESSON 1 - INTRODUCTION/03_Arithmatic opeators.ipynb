# %%
x = 100
y = 200

# %% [markdown]
# Addition

# %%
result = x + y
print(result)
# Out:
# 300

# %% [markdown]
# Substraction

# %%
result = x - y
print(result)
# Out:
# -100

# %% [markdown]
# Multiplication

# %%
a = 3
b = 10
result = a * b
print(result)
# Out:
# 30

# %% [markdown]
# Division (float)- for accuracy

# %%
result = b/a # with single / it gives in float 
print(result)
# Out:
# 3.3333333333333335

# %% [markdown]
# Division (int)

# %%
result = b//a # with double // it gives integer
print(result)
# Out:
# 3

# %% [markdown]
# Modulas operater

# %%
result = x%y
print(x)
# Out:
# 100
